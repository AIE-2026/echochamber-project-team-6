# %% [markdown]
# # C5.01 Corpus agenti - Tema 2
#
#
# Scop: ne uităm la `data/corpus_typed.json`, verificăm distribuția bulelor și alegem ce exemple merită păstrate pentru vector store.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import os
import pandas as pd

while not Path("data").exists():
    os.chdir("..")

DATA_PATH = Path("data/typed/corpus_typed.jsonl")

# %%
DATA_PATH
# Out:
# WindowsPath('data/typed/corpus_typed.jsonl')

# %% [markdown]
# ## 2. Încărcăm corpusul

# %%
df = pd.read_json(DATA_PATH, lines=True)
df.head(2)
# Out:
#                                           id       source_channel  \
# 0  yt_iH8jB4NlV9Y_UgxGvCWbzsvB3I-nSy54AaABAg  georgesimionoficial
# 1  yt_iH8jB4NlV9Y_UgwiYbOpe89FfXbeIpl4AaABAg  georgesimionoficial
#
#   channel_family                                        video_title  \
# 0  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
# 1  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
#
#                                                 text  low_information  \
# 0  Metoda votului cetatenilor din Republica Moldo...            False
# 1  Doamne cu atâtea dovezi și nicio instituție in...            False
#
#    pre_filtered target_specific target_refined        target_l1  ...  \
# 0         False     nicusor_dan    nicusor_dan  Instituții stat  ...
# 1         False          simion         simion    Sovereigntist  ...
#
#   repr_pluralist_present repr_pluralist_strength dem_procedure_rejected  \
# 0                  False                       0                  False
# 1                  False                       0                  False
#
#    dem_procedure_defended  call_to_action_present  call_to_action_strength  \
# 0                   False                    True                        1
# 1                   False                   False                        0
#
#    confidence            discourse_type          discourse_subtype  \
# 0         0.9  T2_grievance_anti_sistem   grievance_conspiratorial
# 1         0.9     T1_suport_personalist  suport_afectiv_suveranist
#
#    type_confidence
# 0             high
# 1           medium
#
# [2 rows x 38 columns]

# %% [markdown]
# ## 3. Vedem structura datelor

# %%
len(df)
# Out:
# 17886

# %%
print("Coloane:")
df.columns
# Out:
# Coloane:
# Index(['id', 'source_channel', 'channel_family', 'video_title', 'text',
#        'low_information', 'pre_filtered', 'target_specific', 'target_refined',
#        'target_l1', 'target_l2', 'stance_to_target', 'primary_target_hint',
#        'target_confidence', 'inst_neg_present', 'inst_neg_strength',
#        'inst_pos_present', 'inst_pos_strength',
#        'epist_hidden_coordination_present',
#        'epist_hidden_coordination_strength',
#        'epist_evidence_verification_present',
#        'epist_evidence_verification_strength',
#        'geo_anti_external_domination_present',
#        'geo_anti_external_domination_strength',
#        'geo_pro_external_anchoring_present',
#        'geo_pro_external_anchoring_strength', 'repr_personalist_present',
#        'repr_personalist_strength', 'repr_pluralist_present',
#        'repr_pluralist_strength', 'dem_procedure_rejected',
#        'dem_procedure_defended', 'call_to_action_present',
#        'call_to_action_strength', 'confidence', 'discourse_type',
#        'discourse_subtype', 'type_confidence'],
#       dtype='str')

# %%
df["discourse_type"].value_counts(dropna=False)
# Out:
# discourse_type
# T2_grievance_anti_sistem      7583
# T1_suport_personalist         4624
# T6_afectiv_pozitional         3726
# T4_conspiratie_externalism    1506
# T3_opozitie_suveranista        261
# T5_pro_democratic_european     186
# Name: count, dtype: int64

# %%
## Exemplu de text pentru fiecare tip de discurs

# %%
for bubble in df["discourse_type"].value_counts().index:
    print("\n" + "="*80)
    print(bubble)
    print("="*80)
    
    sample = df[df["discourse_type"] == bubble]["text"].dropna().head(5)
    
    for i, text in enumerate(sample, 1):
        print(f"\n{i}. {text[:50]}")
# Out:
# ================================================================================
# T2_grievance_anti_sistem
# ================================================================================
#
# 1. Metoda votului cetatenilor din Republica Moldova a
#
# 2. Calin Georgescu si George Simion la puscarieeee!!
#
# 3. S-au furat prin liste suplimentare, într-un sat di
#
# 4. Eu nu cred că caracatița poate fi dată la parte !E
#
# 5. Știu ca există un sistem de vot electronic în care
#
# ================================================================================
# T1_suport_personalist
# ================================================================================
#
# 1. Doamne cu atâtea dovezi și nicio instituție intern
#
# 2. Noi oricum știm asta dar întrebarea mea este domnu
#
# 3. Felicitări și RESPECT George Simion! Nu te opri! V
#
# 4. Haideți in stradă pe 20 iulie!!!! Să dăm jos hoții
#
# 5. MILIOANE DE ROMÂNI DEMNI SUNTEM ALĂTURI DE TINE,GE
#
# ================================================================================
# T6_afectiv_pozitional
# ================================================================================
#
# 1. Adevarul sa fie facut prezent si rezultatul sa fie
#
# 2. Ceea ce face este demn de noi romanii adevarati .
#
# 3. Si de trebuie deposite de combustibil degeaba avem
#
# 4. Dumnezeu sa Binecuvinteze Partidul Aur, 🇹🇩🙏 Români
#
# 5. Felicitari pentru discurs! ❤️🙏🇷🇴 Si pentru consecv
#
# ================================================================================
# T4_conspiratie_externalism
# ================================================================================
#
# 1. Atunci daca aveți dovezi împotriva la Maya Sandu d
#
# 2. Dom-le am văzut cu ochii nostrii cum sa fraudat to
#
# 3. Domnule Simion, cine sunt oamenii acestia si in ce
#
# 4. George pina Mr Trump nu is baga mina nu aveti sans
#
# 5. 2:51 Caaaat? 10.000 Euro la 100.000 urmăritori? O
#
# ================================================================================
# T3_opozitie_suveranista
# ================================================================================
#
# 1. Să zicem că ar fi fost 500 de autocare prin absurd
#
# 2. Eu înteleg că mănânci căcat dar chiar nu ai nicio
#
# 3. deci dovezi lipsa, doar marturii inventate.. bravo
#
# 4. Puneti mana si mai cercetati, nu mai credeti toate
#
# 5. George dacă tu știi că te-au furat atunci nu trebu
#
# ================================================================================
# T5_pro_democratic_european
# ================================================================================
#
# 1. Este ilegal și extrem de riscant să încerci să vot
#
# 2. Nu ajută să vedem asta trebuie să folosiți datele
#
# 3. Mă voi realizați că votul s-a încheiat și Nicușor
#
# 4. PERSPECTIVA MEA E CLA 2:22 RA, E OPTIMA! VOTEZ NIC
#
# 5. PERSPECTIVA MEA E CLARA, E OPTIMA. VOTEZ NICUSOR D

# %% [markdown]
# # 4. Pastram doar 150 de bula

# %%
# Alegem un subset simplu pentru curs: maximum 150 texte per bulă

N_PER_BUBBLE = 150

df_sample = (
    df[df["discourse_type"].notna()]
    .sort_values("type_confidence", ascending=False)
    .groupby("discourse_type", group_keys=False)
    .head(N_PER_BUBBLE)
    .copy()
)

df_sample["discourse_type"].value_counts()
# Out:
# discourse_type
# T3_opozitie_suveranista       150
# T2_grievance_anti_sistem      150
# T1_suport_personalist         150
# T4_conspiratie_externalism    150
# T5_pro_democratic_european    150
# T6_afectiv_pozitional         150
# Name: count, dtype: int64

# %%
# Păstrăm doar coloanele utile și salvăm corpusul pentru etapa următoare

keep_cols = [
    "id", "text", "source_channel", "channel_family", "video_title",
    "target_refined", "stance_to_target",
    "confidence", "discourse_type", "discourse_subtype", "type_confidence"
]

df_sample = df_sample[keep_cols].drop_duplicates(subset="text").copy()

OUT_PATH = Path("data/typed/corpus_c5_sample.jsonl")
df_sample.to_json(OUT_PATH, orient="records", lines=True, force_ascii=False)

print(df_sample.shape)
print(OUT_PATH)
df_sample.head(2)
# Out:
# (896, 11)
# data\typed\corpus_c5_sample.jsonl
#                                               id  \
# 17885  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# 15394  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg
#
#                                                     text     source_channel  \
# 17885  Am toată încrederea că oameni ( de bine ) ca :...  AlephNewsOfficial
# 15394  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...       NicusorDanRO
#
#          channel_family                                        video_title  \
# 17885        mainstream  ATENȚIE: România e „binevenită” să aplice iar ...
# 15394  mainstream_actor  🟢 Declarații de presă comune cu Președintele U...
#
#       target_refined stance_to_target  confidence            discourse_type  \
# 17885         simion             anti         0.9   T3_opozitie_suveranista
# 15394    nicusor_dan             anti         0.9  T2_grievance_anti_sistem
#
#            discourse_subtype type_confidence
# 17885        opozitie_difuza          medium
# 15394  grievance_mobilizator          medium

# %% [markdown]
# ## 5. Exportul bulelor finale
# În această etapă transformăm corpusul tipologizat în fișiere separate, câte unul pentru fiecare bulă finală.
# Codurile `T1`, `T2`, `T3`, `T4`, `T5` vin din adnotare, dar în aplicație folosim numele finale ale agenților:
# | Agent | Personalitate | Cum vorbește | Ce îl definește |
# |---|---|---|---|
# | Personalist-salvator | devotat, admirativ, sigur | laudativ, emoțional, încrezător | vede liderul ca soluție excepțională |
# | Anti-sistem | furios, suspicios, dezamăgit | acuzator, moralizator, direct | vede instituțiile și „sistemul” ca profund compromise |
# | Anti-suveranist | critic, vigilent, defensiv | contestatar, mai argumentativ | respinge liderii și discursul suveranist |
# | Conspiraționist | alarmist, hiper-suspicios | speculativ, revelator, totalizant | explică evenimentele prin forțe ascunse și actori externi |
# | Pro-european | normativ, moderat, legalist | sobru, justificativ, procedural | apără regulile, instituțiile și ancorarea europeană |
# `T6_afectiv_pozitional` nu devine agent principal în C5. Rămâne categorie transversală / rezervă.

# %%
BUBBLES = {
    "T1_suport_personalist": {
        "agent": "Personalist-salvator",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "T2_grievance_anti_sistem": {
        "agent": "Anti-sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "T3_opozitie_suveranista": {
        "agent": "Anti-suveranist",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "T4_conspiratie_externalism": {
        "agent": "Conspiraționist",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "T5_pro_democratic_european": {
        "agent": "Pro-european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

# %%
"""
OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_PER_BUBBLE = 50

for old_type, meta in BUBBLES.items():
    bubble_df = (
        df_sample[df_sample["discourse_type"] == old_type]
        .drop_duplicates(subset="text")
        .head(N_PER_BUBBLE)
        .copy()
    )

    bubble_df["agent"] = meta["agent"]
    bubble_df["slug"] = meta["slug"]
    bubble_df["personality"] = meta["personality"]
    bubble_df["speaks"] = meta["speaks"]
    bubble_df["definition"] = meta["definition"]
    bubble_df["source_type"] = old_type

    out_path = OUT_DIR / f"{meta['slug']}.jsonl"
    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

    print(f"{meta['agent']}: {len(bubble_df)} texte -> {out_path}")

"""
# Out:
# '\nOUT_DIR = Path("data/bubbles")\nOUT_DIR.mkdir(parents=True, exist_ok=True)\n\nN_PER_BUBBLE = 50\n\nfor old_type, meta in BUBBLES.items():\n    bubble_df = (\n        df_sample[df_sample["discourse_type"] == old_type]\n        .drop_duplicates(subset="text")\n        .head(N_PER_BUBBLE)\n        .copy()\n    )\n\n    bubble_df["agent"] = meta["agent"]\n    bubble_df["slug"] = meta["slug"]\n    bubble_df["personality"] = meta["personality"]\n    bubble_df["speaks"] = meta["speaks"]\n    bubble_df["definition"] = meta["definition"]\n    bubble_df["source_type"] = old_type\n\n    out_path = OUT_DIR / f"{meta[\'slug\']}.jsonl"\n    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)\n\n    print(f"{meta[\'agent\']}: {len(bubble_df)} texte -> {out_path}")\n\n'

# %% [markdown]
# ## 6. Alege agentul tău și verifică textele
# Fiecare membru al echipei lucrează pe un singur agent.
# Datele vin din `df_sample`, iar agentul este legat de eticheta tehnică `discourse_type`.
# Scopul este să alegi aproximativ 50 texte bune pentru agentul tău.

# %%
# Alegeți un agent și încărcați textele corespunzătoare pentru etapa următoare
AGENTS = {
    "Personalist-salvator": {
        "type": "T1_suport_personalist",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "Anti-sistem": {
        "type": "T2_grievance_anti_sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "Anti-suveranist": {
        "type": "T3_opozitie_suveranista",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "Conspiraționist": {
        "type": "T4_conspiratie_externalism",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "Pro-european": {
        "type": "T5_pro_democratic_european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

MY_AGENT = "Anti-suveranist"  # Alegeți unul dintre agenți: "Personalist-salvator", "Anti-sistem", "Anti-suveranist", "Conspiraționist", "Pro-european"

meta = AGENTS[MY_AGENT]

my_df = (
    df_sample[df_sample["discourse_type"] == meta["type"]]
    .drop_duplicates(subset="text")
    .copy()
)

print("Agent:", MY_AGENT)
print("Tip discurs:", meta["type"])
print("Texte disponibile:", len(my_df))

my_df[["id", "type_confidence", "discourse_subtype", "text"]].head(2)
# Out:
# Agent: Anti-suveranist
# Tip discurs: T3_opozitie_suveranista
# Texte disponibile: 150
#                                               id type_confidence  \
# 17885  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg          medium
# 15410  yt_6_Hc2S02Duw_Ugytw6-BDQ2pA_Zi-TB4AaABAg          medium
#
#       discourse_subtype                                               text
# 17885   opozitie_difuza  Am toată încrederea că oameni ( de bine ) ca :...
# 15410   opozitie_difuza  Apropo de avalansa de troli ce se devarsa si a...

# %% [markdown]
# ### Cum verifici textele
# Citește textele afișate mai jos.
# Dacă un text este slab, copiază ID-ul lui în lista `REMOVE_IDS`.
# Elimină texte prea scurte, duplicate, ambigue sau care nu exprimă clar vocea agentului.|
#
# - pot sa folosesc un notepad pentru IDs
# daca nu gasesti 50 de comentarii bune, incarca mai multe.
# - poti folosi si alte metode (export text, csv) pentru vizualizarea si alegerea comentariilor

# %%
for _, row in my_df.head(70).iterrows():
    print("=" * 80)
    print("ID:", row["id"])
    print("Confidence:", row["type_confidence"])
    print("Subtype:", row["discourse_subtype"])
    print(row["text"][:700])
# Out:
# ================================================================================
# ID: yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Am toată încrederea că oameni ( de bine ) ca : G Simion , Călinge , dna Găurilă ...... vor avea mare grijă să pună fie piedici , fie bețe-n roate astfel încât să rămanem sub tutela cremlinului
# ================================================================================
# ID: yt_6_Hc2S02Duw_Ugytw6-BDQ2pA_Zi-TB4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Apropo de avalansa de troli ce se devarsa si acum aici si fac apologia nebuniei prin invective, amenintari si minciuni. De cel putin 10 ani blochez si raportez la youtube zilnic uneori zeci de troli/boti cu narative putiniste ce probabil majoritatea vin din softul de boti fara numar, ce fac atacurile astea cibernetice. *Cam cu doua zile inainte de primul tur al alegerilor, au inceput sa se deverse in rafale, repetat, prin mai toate subiectele de pe Youtube, comentarii si indemnuri venite de la diverse conturi de troli sau boti, de a-l vota pe calin georgescu. Nici nu stiam cine mai e si asta. Era socant cum chiar in ziua alegerilor, indemnurile de a vota Georgescu, apareau in sir si cu zecil
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgxQ1N1kdP_MTx8B4K14AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Aceasta nu este o emisiune....este o regizare mizerabilă gen "Cîntarea României !😂
# ================================================================================
# ID: yt_bee6nXyzJ_E_Ugyjnx0utsCXEXc94q54AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# La pregatit bine Putin a investit bani in Guru Georgescu mai bine cu Nicusor decat un mincinos ca Georgica
# ================================================================================
# ID: yt_im3QoqSgfDo_UgwOL2VI3_toiLZSDqh4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Eu am vorbit cu susținători de ai lui CG, îs deranjați de minciuna lui CG, cică i-a zis lui Ghiță să nu-l susțină, 😅😅despre asta trebuia să comenteze Turcescu!
# ================================================================================
# ID: yt_OP3PA47JM_M_UgwrxXRV2SQUdDLdbFd4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Grindeanu este o Matriosca la fel și Simion. Doi tembeli care se închină la Rusi.
# ================================================================================
# ID: yt_6hgc90sLVFw_UgzKEAwJ4lrjMa0IzeB4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Este evident ca fortele din spatele lui simion sunt suficient de puternice si-i asigura destula protectie pentru a avea un asemenea comportament...
# ================================================================================
# ID: yt_R-wmsuFxku4_UgyZ1UUIKqIDPM-tch94AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# FAMILIA GEORGESCU, CRISTELA GEORGESCU, CALIN GEORGESCU VOR SA BAGE VACCINAREA OBLIGATORIE TOATE VACCINURILE = SINDROMUL DOWN SE VAD CLAR LA MICROSCOP, NU VA VACCINATI, MULTUMESC FOARTE FOARTE FOARTE FOARTE MULT
# ================================================================================
# ID: yt_N5Wr2OHINDo_Ugw9Gyk4Ehe3UofP07V4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Adică UDMR a fost cu Psd tot timpul la guvernare și acum ne mirăm că votează ce mai propune AUR?? Suntem oare așa naivi?
# ================================================================================
# ID: yt_DzqO3anbtUE_UgzcIZK1ev4kPy8en6V4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Cu ce te încălzește ca stai pe o mină de aur dacă nu profiți de asta?? Homeless?? Veți fi despăgubiți gras mai mult decât valorează casa dacă era oriunde altundeva. Asta nu e activism, e campanie de pregătire a negocierii 😂 semnez petiția ca să aveți un avantaj la negociere, why not?
# ================================================================================
# ID: yt_pfOUEvkf38M_UgydpTbStbf2J2sC1Bp4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Mulțumim pentru explicații! 👍🏼 Acest GS este un biet pion pe tabla de șah a lui Putin. Iar CG e nebunul ...
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgwMwq1Jvcel1wkruXl4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# A Alexandrescu. Ești super deșteaptă felicitariii maxime. Și a arătat adevărata față aomis răspunsurile. .îl invocă pe d zeu crezând. Că prostește. Lumea. Felicitări Anca pt răbdare!
# ================================================================================
# ID: yt_jxIZUCUPnAw_UgwsgJb1kB8dDmDGjEB4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Păi cum facem? America ta, care ne apără de toate relele lumii, ne-a furat totuși alegerile. Nu cumva America a luat-o razna și, cu susținători ca tine, e posibil să dea foc lumii? Gândește-te numai la milioanele de oameni uciși pe timpul vieții noastre peste tot prin lume înainte să le mai sufli în fund. Cele 165 de fetițe ucise recent nu ți-au dat deloc de gândit? Sau ordinul de zi pe unitate trebuie îndeplinit întocmai și la timp? Cu susținători ca tine Georgescu incepe să piardă din portanță și e cumva păcat.
# ================================================================================
# ID: yt_idoJioeeSSw_UgziAh0tD5cvY8lzbSB4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Pare adus cu forta, fara sotie, fara un sunet. In toata compania electorala, un cuvant nu a spus despre tine. O singura data nu a pronuntat " Votati George Simion!" Nu stiu de ce, dar din 19 mai cred ca vom afla si de ce. Stiu ca sunt dorite cele 2 milioane de voturi, dar sunt atat de multe zile pana la alegeri... se duc voturile de la tine. Oamenii nu mai pot fi manipulati, iar adevarul va iesi la iveala. Tic-tac
# ================================================================================
# ID: yt_Vekhmz5OPCc_UgzpXOYhxlT3Nqo6h7J4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# jigodia aia de Georgescu nu lua intrebari inca din campanie, cand NU AVEA PUTEREA ,cum zic americanii writings were on the wall'' scria clar pe perete ce va face avand puterea
# ================================================================================
# ID: yt_xSxPpRcYQp0_Ugw07l-sNuQ1fxFsAyZ4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Ai inceput cu o minciuna. Tu ai refuzat cu obstinatie orice confruntare fata in fata cu ceilalti!! Te sfatuiesc sa te dezici pur si simplu de acest C. Georgescu daca ajungi presedinte. Nu avem nevoie de acest individ care se crede Mesia. Este bolnav patologic.
# ================================================================================
# ID: yt_jvV4hfEOyQM_UgwlhJNkjmaxM_KOs5F4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Si ce daca a fost scoasa? Traim si fara America. Oricum alegatorii lui Simion nu-si permit. Numai liderul lor.
# ================================================================================
# ID: yt_RyS5VvxNsbg_UgxMhWZPZS_Z7_Zne0p4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Înainte cu manipularea !! Asta e propaganda voastrā , vise nostalgice de comunism !
# ================================================================================
# ID: yt_y2972A4bDYg_Ugxcrlw06E6oGqXJ-QN4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Dacă nu omori marionetele păpușarului, dai din gură fără rost. Omarai pe grinfldeni, bolovani, salvatori. Nu îi omori, ei merg mai departe. Dați din gură fără soluții.
# ================================================================================
# ID: yt_opXUERp44N4_UgxET0XNJVj_05O-UvN4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# A venit si paduchele Potra cu cadouri pentru Messia Georgescu!😅
# ================================================================================
# ID: yt_y2972A4bDYg_UgwjAr_AgQ1TpSSgTjV4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Calin Georgescu a participat la turul unu ca sa fie anulat si sa nu castige alegerile, asa face el , cere bani ca sa nu i se dea!😅😅😅
# ================================================================================
# ID: yt_y2972A4bDYg_UgyETptLmRoLZvxC0Kl4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Cred ca AUR-ul e trans in jos chiar de Simion,cand vorbim de imaginea partidului si increderea pe care o emana,lumea am vazut ca se uita la varf si identifica partidul cu seful acestuia...iar in cazul asta Simion nu prea mai ajuta...zic si eu.
# ================================================================================
# ID: yt_y2972A4bDYg_UgyvNCHLQrRRDSVuFet4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# DIN PĂCATE domnul Georgescu este o iluzie . Și domnia sa face parte din jocul de prostire a bietului popor .
# ================================================================================
# ID: yt_97qXZe3_J_k_Ugz_-EFMa2xlR3TvdAh4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Pentru ,,viata de cacat " care va sa vie trebuie multumit prietenilor de peste Atlantic. Nimic bun nu o sa se intample. O sa fie din ce in ce mai rau.
# ================================================================================
# ID: yt_HVX355umuMI_UgwdrQX26BJsc3znQ8V4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Mai ești nebun? De unde au decis pe cineva care s-a folosit de numele lui Trump, apoi când a căzut s-a dat de partea rușilor. Ce linoleum fumezi?
# ================================================================================
# ID: yt_97qXZe3_J_k_UgyKqtqkIsf3Ha9K1UB4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Am vandut si Dacia. Daca se mai inchide si fabrica de la Mihoveni atunci Dacia ramane doar o amintire pentru romani si un producator francez.
# ================================================================================
# ID: yt_U7pHadpd4IE_UgyKATn1VaAZzqJTwWJ4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Eu NU VOTEZ SIMION, pentru că iau în considerare spusele lui Călin Georgescu despre Simion în NOIEMBRIE 2024 : ,,Domnilor și doamnelor din partidul AUR. Vă întreb ,sincer, sunteți siguri ca George Simion este omul care poate conduce România? Stiți de ce nu am acceptat propunerile lui George Simion de a fi premier ,sau de a candida din partea AUR la ,,preșidenție,,(aici habar n-are că este vorba de ,,președinție)? Pentru ca George Simion nu este omul oamenilor lui, al celor care cu adevărat îl susțin. El este omul altora. Al celor care nu au nimic în comun cu binele poporului.,,
# ================================================================================
# ID: yt_dESUmtdVSzo_Ugz4DFZglJGGKef0cpN4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Poate pentru ca e membru AUR Neamtu face si el politica celor 2 buci dar el personal vede lucrurile altfel
# ================================================================================
# ID: yt_yEuctxNb4O0_UgwHXBIOHHnaHTFWHkp4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# o analiză detaliată, dar trebuie să fim foarte atenți la cum abordăm subiectele politice, mai ales când e vorba de partide și conflicte. Este important să discutăm într-un mod respectuos și informat, având în vedere că astfel de subiecte pot fi foarte sensibile și pot avea un impact puternic asupra opiniei publice. Cum poate opoziția din partidu AUR să încerce să erodeze democrația? Manipularea narativului Opoziția poate încerca să submineze încrederea cetățenilor în instituțiile democratice, prin diseminarea unor narațiuni false sau distorsionate. Dacă aceștia reîntăresc ideea că democrația este "coruptă" sau "ineficientă", oamenii ar putea ajunge să devină cinici și să piardă încrederea în
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgwjwigWAVszTisoINV4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Eu sunt in diaspora,avem un grup whatsap cu colegii din liceu dintre care unul e preot la Milano! Inainte de primul tur ne a trimis pe grup un articol prin care ne sfatuia sa votam cu suveranistul!!!! Am ramas toti masca!
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgzrVk8bsVf_9_hr3ZJ4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Voi New Age-istii va faceți adepți discreditând Biserica. Sosoaca face astfel de acțiuni din poziția de misionari New Age. Una dintre minciuni e ca ea a salvat biserici. La Muiereasca ea e vinovata pentru scandalul de acolo. A exploatat o situație cu scopul sa îl ducă acolo pe falsul preot Adrian Singurov, care e din clica New Age ista a lu8 Șoșoacă. Sosoaca bate câmpii folosind sensibilitățile oamenilor încercând sa-i instige împotriva Bisericii.
# ================================================================================
# ID: yt_97qXZe3_J_k_UgyJBHrc5MFmlR4Cnc54AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# După acțiunile lui NicușorDan eu cred ca la sponsorizat Zelenski
# ================================================================================
# ID: yt_97qXZe3_J_k_UgwoX-lk4oM7CLpY8ap4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Propagandă Rusească. Ăsta e Turcescu. Nici 10/° nu e cu un pro rus Georgescu. Marș la Moscova. 😂😂😂
# ================================================================================
# ID: yt_3MhSvAqrFOA_UgynAzSzwhcKSrMdN6l4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Si cu toate ca nu avea nevoie de nimic, din ce bani a făcut campania? Instruit de cine? Din ce bani plătește gărzile de corp? Era sigur ca o să câștige pentru ca avea susținerea de unde trebuie. Nu toată lumea pune botul la harneala asta.
# ================================================================================
# ID: yt_3MhSvAqrFOA_UgzbJaAVLs2JZ7eCweV4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Sarlatanul Mesia se incurca in atatea minciuni incat a devenit ridicol. Doamne Fereste....sa fii iesit clovnul care mananca fructe de padure.....
# ================================================================================
# ID: yt_5QYDDejaR5E_UgzI_aUlMpDiNpab01h4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Cu respect vă rog ca de Ziua Națională să nu ne separați în 2 tabere: georgiști și auriști. Va fi și Simion la Alba Iulia, vă rog să nu faceți ca Șosoacă care a dezbinat miscarea suveranistă. Doar sistemul soroșist ar avea de câștigat.
# ================================================================================
# ID: yt_3MhSvAqrFOA_UgwLTJyTaFTHKoGwAet4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# DIN PACATE RĂMÂN LA PAREREA LUI IURIE ROȘCA....CG MASON VADIT NEW AGE IST OPOZIȚIA CONTROLATĂ.....😢😢😢😢😢.... ESTE ATÂT DE FIRESC ....NU I VORBA DE GEORGESCU NEAPARAT... PÂNĂ LA CAPĂT ĂSTA ESTE POLITICUL SI CLOACA CE FUGE IREMEDIABIL DUPA O ...PUTERE CE NU EXISTĂ....ILUZII MATRIX CONSUMATOR DE ENERGIE A VISELOR A CELOR CARE NU SE MAI OPRESC DIN VISAT....😢
# ================================================================================
# ID: yt_97qXZe3_J_k_UgzRZH26v230V5fzOkJ4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Dupa cum da , acum cand a iesit presedintele Romaniei, para- ndarat Ucrainei, putem presupune ca i-au venit bani si de acolo, in campanie. Ma surprinde de fiecare data sa il aud cu cata convingere afirma el ca vom ajuta Ucraina pana la capat! Care capat?! Pana da faliment tara noastra.
# ================================================================================
# ID: yt_97qXZe3_J_k_Ugyix5h7BSdGZULBUwF4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Idiotul national o fi luat si de la Zelenski si acum i-a dat gazul!
# ================================================================================
# ID: yt_97qXZe3_J_k_UgyvSEpkdz35HK6Auhh4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Și Becali a zis că s-a întâlnit cu el, a vorbit de campanie da nu a vrut bani
# ================================================================================
# ID: yt_97qXZe3_J_k_UgzqZgdhWELujX_pMPR4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Avem noi impresia că nu se știe de unde a avut "harpalete"bani!!Ei știu si ce nu avem nu doar ce avem!!
# ================================================================================
# ID: yt_5AGO7BTxl_U_UgwNrH8-xmNOuPkxNIF4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Nu pot sa cred aproape la egalitate diáspora si se stia clar c 80% sunt su simion Si asa a fost Manipulare a voturilor la greu
# ================================================================================
# ID: yt_5AGO7BTxl_U_UgzBB8mkwRO8JwP_lE14AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Atata dezinformare si manipulare ca la Realitatea plus,nu am vazut niciodata!Eu sunt din diaspora si am votat cu tot sufletul Nicuso Dan.Nu mi-as fi dorit niciodata sa ma reprezinte unul ca Simion.
# ================================================================================
# ID: yt_hffDDldq0nI_UgxZf_sNe_IGeS2Gdrl4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Și atunci de ce nu face contestație dl Georgescu? Ce are a face CCR cu rezultatele alegerilor? Nu are Comisia Electorală competența de a valida alegerile? Dreptul la vot este scris în Constituție.
# ================================================================================
# ID: yt_NQjjXSi3Ayk_Ugyqz6uAEijnGJb9S8F4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Robert,nu pica in capcana cu AUR 40%,atunci ceilalti au 60%.Dar la alegeri reale,AUR nu ia 20%
# ================================================================================
# ID: yt_zMTwPsQ26ZI_UgwSMJDiA_uqwHbI9Yh4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Parca mai zicea cineva că toți copii sunt genii.... Calin Georgescu .
# ================================================================================
# ID: yt_5AGO7BTxl_U_Ugwrf6lv6UEEW_T4I1l4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Ultimul interviu a lui Georgescu la Gândul l-a scos pe Simion din cursa. Cine ar alege un " copil neastamparat"?
# ================================================================================
# ID: yt_IDHDLcsiSZA_UgyeXNYzlSBY0TBtJMl4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Cracanici și Sosoaca au dezinformat tot timpul oamenii ușor de manipulat! Felicitări Recorder!
# ================================================================================
# ID: yt_tvoAP1ZrdjY_Ugz0FxrfYkqWs-owErl4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Lumea nu vede că Aur este cu două fețe când cu turci când cu Rușii când cu Americanii
# ================================================================================
# ID: yt_0t6khZTkmxM_UgyAvGuYhrMIKsHLnXN4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Aloooo,AUR ati gesit sistematic! De ce nu cere re numararea voturilor?🤷🏻‍♀️
# ================================================================================
# ID: yt_0t6khZTkmxM_UgzY0uNDjyEsCPGfEX94AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# CACARAU...tu ești ofertă ???! M-ai iei tratament ??este tot un fel de USL ???tu ai șanse...cu GEORGESCU ???! Belgia...
# ================================================================================
# ID: yt_5AGO7BTxl_U_UgzeXqeQIZuQBvMdoWp4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Anca a contribuit si a legitimat minciuna cu rusii prin intrebarea ei obsesiva "sigur nu vin rusii dle CG".
# ================================================================================
# ID: yt_JS0gQo-HQ3A_UgxODoyTH17sh9ucptp4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Nu se mai aude nimic de Amalia Belantoni...măi tanti cu masoneria, ești celebră și în cazul donațiilor din campania electorală pentru europarlamentare din 2024...
# ================================================================================
# ID: yt_rdk-bvlyVEA_UgwnmSh7JXjSW4ZnM6l4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Pai nu dorea Iohanis sa-l pună prim-ministru ce dracu faceți pe prostii.In primul tur.Georgescu a fost promovat sa distrugă curentul suveranist.Dobitocul asta de agent SIE face pe neștiutorul.
# ================================================================================
# ID: yt_5AGO7BTxl_U_Ugw72YIgbJZlVA6lmiR4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# CE ATI INVATAT DIN ACESTE 6 LUNI zice alexandra . AM INVATAT CA REALITATEA TV sa transformat in MARS TV dezbinand oamenii prin minciuni si manipulare, poporul se pare ca sa trezit in constiinta dar nu pentru voi , azi zi mare in care poporul a decis, jos cu extremismul jos cu manipularile, jos cu suveranii, jos cu secta georgescu, jos cu voi toti,
# ================================================================================
# ID: yt_5AGO7BTxl_U_UgyScQ_6YXn5peSZ1XR4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Băi băieți ..,..Simion împreună cu Georgescu AU ŞUNTAT-O PE DIANA ŞOŞOACĂ ..ŞI SOS ROMÂNIA …ȘI DIN CAUZA ASTA S-A DUS DRACU SIARTA TUTUROR ROMÂNILOR…!!!
# ================================================================================
# ID: yt_XP-HViPnqMk_UgxmqQyAu_YPnGSqHFV4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Căline, tu, în jurul căruia s-a coagulat devoțiunea nețărmurită a adepților tăi, acceptă-ți înscăunarea autocratică peste destinele lor și îndrumă-i în pribegie anarhică, acolo unde le va fi purtată retina de hazard și impuls, pentru ca ei să-și perpetueze existența într-un exercițiu neîntrerupt de glorificare encomiastică a numelui tău
# ================================================================================
# ID: yt_bYkEGaz6kK4_UgxcGmfi0hH6QvK8CqJ4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# mmmmm Am crezut în tine Omule ,,, Te-am Votat ,,,, Dar acum vad de 1 AN Ca dansezi LAMBADA , Si dai sperante desarte Poporului ROMÂN ( Trump si Netanjahu ) ??? Speranta Poporului ROMÂN SA VINA DE LA EI ??? SERIOS ??? ASTA NE CERI SA CREDEM SI SA ASTEPTAM ??? mmmm
# ================================================================================
# ID: yt_nAWp0BjBZPc_Ugz8uch1Cjpwmg8kxiF4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# De la 13:00 încolo, Ioana Constantin murea de frică ca nu cumva Papahagi să dea exemplu USR ca acel partid anti-șpagă, ca nu cumva audiența să afle că există și alte partide în afară de PSD și AUR... :)
# ================================================================================
# ID: yt_tvoAP1ZrdjY_Ugw9s0WIp93e9Bw3-vl4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Nu ne-am plictisit de sondajele plătite de derbedeul tuciuriu cu ochi de mort , ca să-l dea pe el cel mai tare din parcarea goală??? Mulți ziceau că va fi președinte , cu 80% , dar l-a făcut șah-mat ND , la singura dezbatere la care a avut curajul să apară!😂😂😂😂😂😂🎉🎉🎉
# ================================================================================
# ID: yt_tvoAP1ZrdjY_Ugy0kTLtLYiw6euQCVh4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Pana nu ajungem iar sub dictatura Rusiei nu ne lasam, ca noi suntem Romani.
# ================================================================================
# ID: yt_Ip7E56J5Ma0_Ugwl8uLcPAjICc7KlQd4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Suntem mai multi ... da... Vreo cateva zeci de spalati pe creier platiti sa fie acolo, la fel ca protestele celor de la aur.
# ================================================================================
# ID: yt_XSS2jUv9oQw_UgwLV_dJqV0ZYurJroR4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Sereila e in tot si in toate, inclusiv aur si tot ce va veni.
# ================================================================================
# ID: yt_XbnkEppuBvc_UgxjSgGbNFDQ_8EtfLt4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Săriți pe el dragi români, trebuie să-i pupați mâinile și picioarele că el este alesul,el este Mântuitorul,el vă arată calea 😂
# ================================================================================
# ID: yt_XbnkEppuBvc_Ugztmt9RH1QzMnYkREh4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Mai oameni buni, cum puteti susține ca Trump vrea pace și prosperitate, cum puteți voi, suveraniștii să îl lăudați, când el a spus clar ca vrea petrolul Venezuelei? Suveraniștii din Venezuela or fi mulțumiți?
# ================================================================================
# ID: yt_7WEHuZIWqhQ_UgwNTAUzjcuHdhM4gtZ4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Mă, voi ăștia cu devoțiunea nețărmurită față de Călin, înscăunați-l autocratic peste destinele voastre și porniți în pribegie anarhică, acolo unde vă poartă retina și hazardul, perpetuându-vă existența într-un exercițiu continuu de glorificare encomiastică a numelui său, încredințați fiind că printr-o asemenea rânduială providențială ne va fi tuturor hărăzită o conviețuire idilică, prelungită până la adâncimi senectuțiale fericit asimptotice
# ================================================================================
# ID: yt_RU8h59PnVDM_Ugxw6Vquj0Br3S0VMGV4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Lepra aia care ia interval este non stop lângă el cine o fi 🙊🙈🙉🗣🗝
# ================================================================================
# ID: yt_NQjjXSi3Ayk_Ugzv6P0aEgx1vMJCdWd4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Puteti sa "cautati"cauzele pentru care Simion a plimbat marea masa a protestatorilor pe o ruta in afara zonei centrale, guvernamentale - pana la Cotroceni unde au fost doar blindate de jamdarmi- pana a epuizat pe toti cei ce iesisera la protest. Pur si simplu dubioasa "decizia"lui Simion. Si de atunci ...romanii nu mai ies la proteste, le-a stins orice speranta. Dubios dl Simion, f dubios.
# ================================================================================
# ID: yt_5fQedgUqKls_UgyjcWBPQ_3Lze3105t4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# AUR, SOS si POT sunt partide pro-Rusia care vor ca Romania sa devină un stat fascist.
# ================================================================================
# ID: yt_1ug-9Ub6LfQ_Ugz96_hvF8sIfEsZRep4AaABAg
# Confidence: medium
# Subtype: opozitie_difuza
# Domnul Makiaveli, nu cumva, este pus de Șoșoacă să facă astfel de dezvăluiri?

# %%
# elimin textele slabe și păstrez 50

REMOVE_IDS = [
    "yt_bee6nXyzJ_E_UgxQ1N1kdP_MTx8B4K14AaABAg",
    "yt_1ug-9Ub6LfQ_Ugz96_hvF8sIfEsZRep4AaABAg"
]

clean_df = (
    my_df[~my_df["id"].isin(REMOVE_IDS)]
    .head(50)
    .copy()
)

clean_df["agent"] = MY_AGENT
clean_df["slug"] = meta["slug"]
clean_df["personality"] = meta["personality"]
clean_df["speaks"] = meta["speaks"]
clean_df["definition"] = meta["definition"]

print("Texte finale:", len(clean_df))
clean_df[["id", "agent", "text"]].head()
# Out:
# Texte finale: 50
#                                               id            agent  \
# 17885  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg  Anti-suveranist
# 15410  yt_6_Hc2S02Duw_Ugytw6-BDQ2pA_Zi-TB4AaABAg  Anti-suveranist
# 3277   yt_bee6nXyzJ_E_Ugyjnx0utsCXEXc94q54AaABAg  Anti-suveranist
# 3215   yt_im3QoqSgfDo_UgwOL2VI3_toiLZSDqh4AaABAg  Anti-suveranist
# 2882   yt_OP3PA47JM_M_UgwrxXRV2SQUdDLdbFd4AaABAg  Anti-suveranist
#
#                                                     text
# 17885  Am toată încrederea că oameni ( de bine ) ca :...
# 15410  Apropo de avalansa de troli ce se devarsa si a...
# 3277   La pregatit bine Putin a investit bani in Guru...
# 3215   Eu am vorbit cu susținători de ai lui CG, îs d...
# 2882   Grindeanu este o Matriosca la fel și Simion. D...

# %% [markdown]
# ### Descrierea agentului tău
# Înainte să exporți bula curată, descrie în 5–7 rânduri ce fel de voce discursivă are agentul ales.
# Nu descrie o persoană reală. Descrie un tip de discurs observat în corpus.
# Răspunde la aceste întrebări:
# - Cum vede acest agent instituțiile, politica sau actorii publici?
# - Ce ton folosește cel mai des?
# - Ce tip de argumente sau acuzații apar frecvent?
# - Ce îl diferențiază de celelalte bule?
# - Ce ar trebui să păstreze un viitor agent AI ca să sune coerent cu această bulă?

# %% [markdown]
# descriere:
#
# • Agentul anti-suveranist vede discursul suveranist ca pe un pericol politic și social, asociat frecvent cu propaganda rusă și manipularea publică.
#
# • Folosește un ton critic, defensiv și uneori ironic atunci când vorbește despre liderii suveraniști sau susținătorii lor.
#
# • Acest tip de discurs acuză frecvent existența trollilor, a dezinformării și a influențelor externe asupra opiniei publice.
#
# • Argumentele sale susțin orientarea pro-europeană, instituțiile democratice și distanțarea de propaganda Kremlinului.
#
# • Spre deosebire de alte bule, agentul anti-suveranist încearcă să demonteze narative conspiraționiste și populiste.
#
# • Limbajul este direct, contestatar și orientat spre combaterea dezinformării și manipulării online.
#
# • Un viitor agent AI construit pe această bulă ar trebui să păstreze tonul critic, argumentativ și orientarea pro-democratică.

# %%
# export bula curată pentru etapa următoare
OUT_DIR = Path("data/bubbles")

OUT_DIR.mkdir(parents=True, exist_ok=True)

out_path = OUT_DIR / "anti_suveranist.jsonl"

clean_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

print("Salvat:", out_path)
# Out:
# Salvat: data\bubbles\anti_suveranist.jsonl

# %% [markdown]
# Am curățat bula discursivă „Anti-suveranist”.
#
# Majoritatea textelor selectate critică discursurile naționaliste, conspiraționiste sau pro-ruse și susțin valorile democratice și orientarea pro-europeană.
#
# Tonul folosit este în general critic, ironic și opozitiv față de actorii politici percepuți ca extremiști sau manipulatori.
#
# Am identificat câteva texte ambigue sau prea vagi pentru vocea agentului și le-am eliminat folosind lista REMOVE_IDS.
#
# Corpusul final reprezintă bine vocea agentului deoarece păstrează consecvent aceeași perspectivă anti-suveranistă și anti-propagandă.
#
# Un viitor agent AI construit pe această bulă ar trebui să păstreze tonul critic, argumentativ și orientarea pro-democratică și pro-europeană.
