# %% [markdown]
# # C5.01 Corpus agenti - Tema 2
#
#
# Scop: ne uităm la `data/corpus_typed.json`, verificăm distribuția bulelor și alegem ce exemple merită păstrate pentru vector store.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import os
import pandas as pd

PROJECT_ROOT = Path(r"C:\Users\mihai\OneDrive\Desktop\Facultate\Master\Semestre\S4\Ai_engineering\echochamber-project-team-6")
os.chdir(PROJECT_ROOT)
DATA_PATH = Path("data/typed/corpus_typed.jsonl")

# %%
DATA_PATH
# Out:
# WindowsPath('data/typed/corpus_typed.jsonl')

# %% [markdown]
# ## 2. Încărcăm corpusul

# %%
df = pd.read_json(DATA_PATH, lines=True)
df.head(2)
# Out:
#                                           id       source_channel  \
# 0  yt_iH8jB4NlV9Y_UgxGvCWbzsvB3I-nSy54AaABAg  georgesimionoficial
# 1  yt_iH8jB4NlV9Y_UgwiYbOpe89FfXbeIpl4AaABAg  georgesimionoficial
#
#   channel_family                                        video_title  \
# 0  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
# 1  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
#
#                                                 text  low_information  \
# 0  Metoda votului cetatenilor din Republica Moldo...            False
# 1  Doamne cu atâtea dovezi și nicio instituție in...            False
#
#    pre_filtered target_specific target_refined        target_l1  ...  \
# 0         False     nicusor_dan    nicusor_dan  Instituții stat  ...
# 1         False          simion         simion    Sovereigntist  ...
#
#   repr_pluralist_present repr_pluralist_strength dem_procedure_rejected  \
# 0                  False                       0                  False
# 1                  False                       0                  False
#
#    dem_procedure_defended  call_to_action_present  call_to_action_strength  \
# 0                   False                    True                        1
# 1                   False                   False                        0
#
#    confidence            discourse_type          discourse_subtype  \
# 0         0.9  T2_grievance_anti_sistem   grievance_conspiratorial
# 1         0.9     T1_suport_personalist  suport_afectiv_suveranist
#
#    type_confidence
# 0             high
# 1           medium
#
# [2 rows x 38 columns]

# %% [markdown]
# ## 3. Vedem structura datelor

# %%
len(df)
# Out:
# 17886

# %%
print("Coloane:")
df.columns
# Out:
# Coloane:
# Index(['id', 'source_channel', 'channel_family', 'video_title', 'text',
#        'low_information', 'pre_filtered', 'target_specific', 'target_refined',
#        'target_l1', 'target_l2', 'stance_to_target', 'primary_target_hint',
#        'target_confidence', 'inst_neg_present', 'inst_neg_strength',
#        'inst_pos_present', 'inst_pos_strength',
#        'epist_hidden_coordination_present',
#        'epist_hidden_coordination_strength',
#        'epist_evidence_verification_present',
#        'epist_evidence_verification_strength',
#        'geo_anti_external_domination_present',
#        'geo_anti_external_domination_strength',
#        'geo_pro_external_anchoring_present',
#        'geo_pro_external_anchoring_strength', 'repr_personalist_present',
#        'repr_personalist_strength', 'repr_pluralist_present',
#        'repr_pluralist_strength', 'dem_procedure_rejected',
#        'dem_procedure_defended', 'call_to_action_present',
#        'call_to_action_strength', 'confidence', 'discourse_type',
#        'discourse_subtype', 'type_confidence'],
#       dtype='object')

# %%
df["discourse_type"].value_counts(dropna=False)
# Out:
# discourse_type
# T2_grievance_anti_sistem      7583
# T1_suport_personalist         4624
# T6_afectiv_pozitional         3726
# T4_conspiratie_externalism    1506
# T3_opozitie_suveranista        261
# T5_pro_democratic_european     186
# Name: count, dtype: int64

# %% [markdown]
# ## Exemplu de text pentru fiecare tip de discurs

# %%
for bubble in df["discourse_type"].value_counts().index:
    print("\n" + "="*80)
    print(bubble)
    print("="*80)
    
    sample = df[df["discourse_type"] == bubble]["text"].dropna().head(5)
    
    for i, text in enumerate(sample, 1):
        print(f"\n{i}. {text[:50]}")
# Out:
# ================================================================================
# T2_grievance_anti_sistem
# ================================================================================
#
# 1. Metoda votului cetatenilor din Republica Moldova a
#
# 2. Calin Georgescu si George Simion la puscarieeee!!
#
# 3. S-au furat prin liste suplimentare, într-un sat di
#
# 4. Eu nu cred că caracatița poate fi dată la parte !E
#
# 5. Știu ca există un sistem de vot electronic în care
#
# ================================================================================
# T1_suport_personalist
# ================================================================================
#
# 1. Doamne cu atâtea dovezi și nicio instituție intern
#
# 2. Noi oricum știm asta dar întrebarea mea este domnu
#
# 3. Felicitări și RESPECT George Simion! Nu te opri! V
#
# 4. Haideți in stradă pe 20 iulie!!!! Să dăm jos hoții
#
# 5. MILIOANE DE ROMÂNI DEMNI SUNTEM ALĂTURI DE TINE,GE
#
# ================================================================================
# T6_afectiv_pozitional
# ================================================================================
#
# 1. Adevarul sa fie facut prezent si rezultatul sa fie
#
# 2. Ceea ce face este demn de noi romanii adevarati .
#
# 3. Si de trebuie deposite de combustibil degeaba avem
#
# 4. Dumnezeu sa Binecuvinteze Partidul Aur, 🇹🇩🙏 Români
#
# 5. Felicitari pentru discurs! ❤️🙏🇷🇴 Si pentru consecv
#
# ================================================================================
# T4_conspiratie_externalism
# ================================================================================
#
# 1. Atunci daca aveți dovezi împotriva la Maya Sandu d
#
# 2. Dom-le am văzut cu ochii nostrii cum sa fraudat to
#
# 3. Domnule Simion, cine sunt oamenii acestia si in ce
#
# 4. George pina Mr Trump nu is baga mina nu aveti sans
#
# 5. 2:51 Caaaat? 10.000 Euro la 100.000 urmăritori? O
#
# ================================================================================
# T3_opozitie_suveranista
# ================================================================================
#
# 1. Să zicem că ar fi fost 500 de autocare prin absurd
#
# 2. Eu înteleg că mănânci căcat dar chiar nu ai nicio
#
# 3. deci dovezi lipsa, doar marturii inventate.. bravo
#
# 4. Puneti mana si mai cercetati, nu mai credeti toate
#
# 5. George dacă tu știi că te-au furat atunci nu trebu
#
# ================================================================================
# T5_pro_democratic_european
# ================================================================================
#
# 1. Este ilegal și extrem de riscant să încerci să vot
#
# 2. Nu ajută să vedem asta trebuie să folosiți datele
#
# 3. Mă voi realizați că votul s-a încheiat și Nicușor
#
# 4. PERSPECTIVA MEA E CLA 2:22 RA, E OPTIMA! VOTEZ NIC
#
# 5. PERSPECTIVA MEA E CLARA, E OPTIMA. VOTEZ NICUSOR D

# %% [markdown]
# # 4. Pastram doar 150 de bula

# %%
# Alegem un subset simplu pentru curs: maximum 150 texte per bulă

N_PER_BUBBLE = 150

df_sample = (
    df[df["discourse_type"].notna()]
    .sort_values("type_confidence", ascending=False)
    .groupby("discourse_type", group_keys=False)
    .head(N_PER_BUBBLE)
    .copy()
)

df_sample["discourse_type"].value_counts()
# Out:
# discourse_type
# T3_opozitie_suveranista       150
# T2_grievance_anti_sistem      150
# T1_suport_personalist         150
# T4_conspiratie_externalism    150
# T5_pro_democratic_european    150
# T6_afectiv_pozitional         150
# Name: count, dtype: int64

# %%
# Păstrăm doar coloanele utile și salvăm corpusul pentru etapa următoare

keep_cols = [
    "id", "text", "source_channel", "channel_family", "video_title",
    "target_refined", "stance_to_target",
    "confidence", "discourse_type", "discourse_subtype", "type_confidence"
]

df_sample = df_sample[keep_cols].drop_duplicates(subset="text").copy()

OUT_PATH = Path("data/typed/corpus_c5_sample.jsonl")
df_sample.to_json(OUT_PATH, orient="records", lines=True, force_ascii=False)

print(df_sample.shape)
print(OUT_PATH)
df_sample.head(2)
# Out:
# (896, 11)
# data\typed\corpus_c5_sample.jsonl
#                                               id  \
# 17885  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# 15394  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg
#
#                                                     text     source_channel  \
# 17885  Am toată încrederea că oameni ( de bine ) ca :...  AlephNewsOfficial
# 15394  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...       NicusorDanRO
#
#          channel_family                                        video_title  \
# 17885        mainstream  ATENȚIE: România e „binevenită” să aplice iar ...
# 15394  mainstream_actor  🟢 Declarații de presă comune cu Președintele U...
#
#       target_refined stance_to_target  confidence            discourse_type  \
# 17885         simion             anti         0.9   T3_opozitie_suveranista
# 15394    nicusor_dan             anti         0.9  T2_grievance_anti_sistem
#
#            discourse_subtype type_confidence
# 17885        opozitie_difuza          medium
# 15394  grievance_mobilizator          medium

# %% [markdown]
# ## 5. Exportul bulelor finale
# În această etapă transformăm corpusul tipologizat în fișiere separate, câte unul pentru fiecare bulă finală.
# Codurile `T1`, `T2`, `T3`, `T4`, `T5` vin din adnotare, dar în aplicație folosim numele finale ale agenților:
# | Agent | Personalitate | Cum vorbește | Ce îl definește |
# |---|---|---|---|
# | Personalist-salvator | devotat, admirativ, sigur | laudativ, emoțional, încrezător | vede liderul ca soluție excepțională |
# | Anti-sistem | furios, suspicios, dezamăgit | acuzator, moralizator, direct | vede instituțiile și „sistemul” ca profund compromise |
# | Anti-suveranist | critic, vigilent, defensiv | contestatar, mai argumentativ | respinge liderii și discursul suveranist |
# | Conspiraționist | alarmist, hiper-suspicios | speculativ, revelator, totalizant | explică evenimentele prin forțe ascunse și actori externi |
# | Pro-european | normativ, moderat, legalist | sobru, justificativ, procedural | apără regulile, instituțiile și ancorarea europeană |
# `T6_afectiv_pozitional` nu devine agent principal în C5. Rămâne categorie transversală / rezervă.

# %%
BUBBLES = {
    "T1_suport_personalist": {
        "agent": "Personalist-salvator",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "T2_grievance_anti_sistem": {
        "agent": "Anti-sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "T3_opozitie_suveranista": {
        "agent": "Anti-suveranist",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "T4_conspiratie_externalism": {
        "agent": "Conspiraționist",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "T5_pro_democratic_european": {
        "agent": "Pro-european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

# %%
"""
OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_PER_BUBBLE = 50

for old_type, meta in BUBBLES.items():
    bubble_df = (
        df_sample[df_sample["discourse_type"] == old_type]
        .drop_duplicates(subset="text")
        .head(N_PER_BUBBLE)
        .copy()
    )

    bubble_df["agent"] = meta["agent"]
    bubble_df["slug"] = meta["slug"]
    bubble_df["personality"] = meta["personality"]
    bubble_df["speaks"] = meta["speaks"]
    bubble_df["definition"] = meta["definition"]
    bubble_df["source_type"] = old_type

    out_path = OUT_DIR / f"{meta['slug']}.jsonl"
    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

    print(f"{meta['agent']}: {len(bubble_df)} texte -> {out_path}")

"""
# Out:
# '\nOUT_DIR = Path("data/bubbles")\nOUT_DIR.mkdir(parents=True, exist_ok=True)\n\nN_PER_BUBBLE = 50\n\nfor old_type, meta in BUBBLES.items():\n    bubble_df = (\n        df_sample[df_sample["discourse_type"] == old_type]\n        .drop_duplicates(subset="text")\n        .head(N_PER_BUBBLE)\n        .copy()\n    )\n\n    bubble_df["agent"] = meta["agent"]\n    bubble_df["slug"] = meta["slug"]\n    bubble_df["personality"] = meta["personality"]\n    bubble_df["speaks"] = meta["speaks"]\n    bubble_df["definition"] = meta["definition"]\n    bubble_df["source_type"] = old_type\n\n    out_path = OUT_DIR / f"{meta[\'slug\']}.jsonl"\n    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)\n\n    print(f"{meta[\'agent\']}: {len(bubble_df)} texte -> {out_path}")\n\n'

# %% [markdown]
# ## 6. Alege agentul tău și verifică textele
# Fiecare membru al echipei lucrează pe un singur agent.
# Datele vin din `df_sample`, iar agentul este legat de eticheta tehnică `discourse_type`.
# Scopul este să alegi aproximativ 50 texte bune pentru agentul tău.

# %%
# Alegeți un agent și încărcați textele corespunzătoare pentru etapa următoare
AGENTS = {
    "Personalist-salvator": {
        "type": "T1_suport_personalist",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "Anti-sistem": {
        "type": "T2_grievance_anti_sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "Anti-suveranist": {
        "type": "T3_opozitie_suveranista",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "Conspiraționist": {
        "type": "T4_conspiratie_externalism",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "Pro-european": {
        "type": "T5_pro_democratic_european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

MY_AGENT = "Conspiraționist"  # Alegeți unul dintre agenți: "Personalist-salvator", "Anti-sistem", "Anti-suveranist", "Conspiraționist", "Pro-european"

meta = AGENTS[MY_AGENT]

my_df = (
    df_sample[df_sample["discourse_type"] == meta["type"]]
    .drop_duplicates(subset="text")
    .copy()
)

print("Agent:", MY_AGENT)
print("Tip discurs:", meta["type"])
print("Texte disponibile:", len(my_df))

my_df[["id", "type_confidence", "discourse_subtype", "text"]].head(2)
# Out:
# Agent: Conspiraționist
# Tip discurs: T4_conspiratie_externalism
# Texte disponibile: 148
#                                               id type_confidence  \
# 15396  yt_joXkZDqGZQU_UgzFU0NMeTYppU_dHpd4AaABAg          medium
# 3141   yt_X3bwh1-9nUU_Ugzkb5UdoDsVooo_b2V4AaABAg          medium
#
#                  discourse_subtype  \
# 15396  anti_externalism_geopolitic
# 3141            conspiratie_difuza
#
#                                                     text
# 15396  Dar de românii din Ucraina care și-au pierdut ...
# 3141   Ținând cont de microfoane, unde sunt microfoan...

# %% [markdown]
# ### Cum verifici textele
# Citește textele afișate mai jos.
# Dacă un text este slab, copiază ID-ul lui în lista `REMOVE_IDS`.
# Elimină texte prea scurte, duplicate, ambigue sau care nu exprimă clar vocea agentului.|
#
# - pot sa folosesc un notepad pentru IDs
# daca nu gasesti 50 de comentarii bune, incarca mai multe.
# - poti folosi si alte metode (export text, csv) pentru vizualizarea si alegerea comentariilor

# %%
my_df.to_csv("conspirationist_texts.csv", index=False)

# %%
for _, row in my_df.head(70).iterrows():
    print("=" * 80)
    print("ID:", row["id"])
    print("Confidence:", row["type_confidence"])
    print("Subtype:", row["discourse_subtype"])
    print(row["text"][:700])
# Out:
# ================================================================================
# ID: yt_joXkZDqGZQU_UgzFU0NMeTYppU_dHpd4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
#
aABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Ilie Bolojan este atacat nu pentru că ar fi greșit, ci pentru că face ce trebuia făcut de 30 de ani. Reforma doare. Și sistemul reacționează. Doare confortul. Doare ruperea obișnuințelor. Doare atingerea rețelelor și intereselor construite în zeci de ani. Când încerci să miști lucrurile cu adevărat, sistemul se opune. Iar când apar și rezultate, se zvârcolește. Bolojan a făcut o alegere clară. A ales să îndrepte ce au greșit predecesorii lui. A ales responsabilitatea în locul populismului care ne-a adus în impasul economic de azi. A ales, prin asumarea premierului Ilie Bolojan, să declanșeze reforma statului așteptată de aproape trei decenii. Trei decenii de inerție nu se repară ușor. După 6
# ================================================================================
# ID: yt_IvosHezmLX8_Ugz9VkVMkCAsbTo3GeB4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# D-le Manastire, ce intrebare este asta...suntem tara in EU, traim in Europa, este clara pozitia noastra. Ii doare in cot pe americani de noi. Isi fac interesul si doar atat!
# ================================================================================
# ID: yt_IvosHezmLX8_UgzaRupJmXrFZdQxqbt4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Spune că ND tocmai a contribuit la ONU-ul lui Donald, ca să poată măcăi ?!
# ================================================================================
# ID: yt_8XaNWSfaLxE_Ugz-bALZpQK0Zn4_n054AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Tramp e un aliat politic al lui Putin,e cunoscut asta de la început.El nu este nici diplomat,nici politic.Esste un blea,blea!!!!
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgzGwtcjoA9kck6BtfF4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Trump este manipulat de catre Putin si culmea ca nimeni nu obsearva asta. Trump e rusinea Americii, iar America e pe cale sa devina rusinea lumii. Asa un sef de stat incompetent nu a avut America pana acum.
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgzX8m1xNV9AHGEW1gF4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# inca de la primul mandat era suspectat ca este un produs rusesc
# ================================================================================
# ID: yt_M37Lar0c11g_Ugx-k2lsJmqMSdYKthJ4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Buna ziua, as dori sa va atrag atentia asupra Qanon-ului. Evenimentele recente dovedesc multe lucruri din postarile lui Q.
# ================================================================================
# ID: yt_BfMPO67wJ84_UgxZFVRklZ7SmB57lnp4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# suntem in siguranta ... asta pana cand ne trezim cu o racheta balistica care ar fi probabilitatea sa nu ne loveasca? hai ca e matematica, sigur nu va 100%
# ================================================================================
# ID: yt_BfMPO67wJ84_UgyXlWbOjQzFnb9jk314AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# If you depend on others to defend you you are nothing but a sucker ,with aboluty no lesson learn from the past and present
# ================================================================================
# ID: yt_YrAie1rs1gM_UgwYuRUlQRiRghWD65t4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Unul sincer... cred ca e primul si ultimul din viata mea... Ce va urma va iubi Rusia..
# ================================================================================
# ID: yt_0b2_71jAaQs_UgzcnWKSk42qiYjNt494AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# catre cel ce ii scrie discursurile presedintelui: putem pune in mormant expresia "este despre x" ? nu stiu daca e tradusa mecanic din Engleza, dar e stupida. si ca orice lucru ce a fost candva popular, momentul cand il auzi si pe Grindeanu folosind-o, e timpul sa o pui in cui
# ================================================================================
# ID: yt__PIes5dU7Zg_UgzR090y3wtQ-Ajij6J4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Melon 😢i a trimis carabinierii sa ii oprească pe americani să își folosească avioanele în atac din bazele din Italia. Baza de la Deveselu e ofensiva. Poate o rachetă iraniană ne va trezi la realitate. De cine ne apăra americanii? Prezența lor e o amenințare pentru Romania
# ================================================================================
# ID: yt__PIes5dU7Zg_UgydLu5WTPhD3lnUl0h4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Puterea si opozitia sunt in mana aceluiasi regizor. Nu va mai faceti iluzii…!
# ================================================================================
# ID: yt__PIes5dU7Zg_Ugy0EQeSOZbmJiyxeE94AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
#
AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Felicitari pt curaj,desi toti si au ales cu mare grija vorbele,clar ca au o anumita teama.
# ================================================================================
# ID: yt_kLdQS9N5cBU_UgzhiTQONGBknFPjSvl4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# 😮😮😮😂😂😂 este șocat cum procesează informația acest om!!! Zici că are hardul plin + memoria RAM la maxim . Nu știe să răspundă altfel....a învățat de pe foaie și nu iese din tiparul dictat. CEL MAI INCAPABIL ȘI NE FIRESC PREȘEDINTE! Va rămâne în istoria României ca MUCUȘOR / NETERMINATUL ( facultate oka terminată, o alta prin Franța cu fff multe semne de întrebare, totul cu o spălare completă....made in România, ca să pară real).
# ================================================================================
# ID: yt_Ds7YVeTvAAY_UgwvbVI8UvDFLsTRwJp4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Avem nevoie de *SUSTINERE PUBLICA pentru Domnul BOLOJAN si Guvern* in reformele si demersurile dificile pe care le au de facut !!! *Hidra psd ii pandeste la orice colt* !!!
# ================================================================================
# ID: yt_Ds7YVeTvAAY_Ugybc0bDlpo7BqYQ5Sd4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# *Vad ca s-au ‘activat’ imediat, trolii si botii ruznaci - semn ca domnul NICUSOR DAN FACE CE TREBUIE pentru Romania* !!!
# ================================================================================
# ID: yt_Ds7YVeTvAAY_Ugx2nKst-UvDb7Mb-cR4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Consiliul pentru pace este o noua schema a lui Trump !Romania trebuie sa sustina organizatiile deja existente si sa se alature partenerilor din UE in aceasta problema!
# ================================================================================
# ID: yt_ZAJeeVgVvYc_UgxME8W5mOW3Z3dKjt14AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# *Vad ca s-au ‘activat’ trolii si botii ruznaci, semn ca domnul NICUSOR DAN FACE CE TREBUIE pentru Romania !!!*
# ================================================================================
# ID: yt_ZAJeeVgVvYc_UgycMVcU4VFxG90z9wJ4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Tot asa de frumos si de elegant, ar fi raspuns si… 🪑 *Nu-i asa, sugeranistilor ?* 😂😂😂
# ================================================================================
# ID: yt_KETrGGaXRpk_UgzyiJhiHkuNgpHgkaF4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Emetiral!!! ... pe de altă parte, așa cum am tot așteptat(în zadar) marturii ale foștilor elevi ai lui Johannisl - tot așa aștept să-i văd părinții lui Nicușor, familia, colegii, locurile eclozării sale. Sau ăsta e făcut prin partenogeneza?!?
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgxE1hfPxL_gF0kt8ap4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Cred că Trump e șantajat cumva de Putin, altfel nu se explică felul în care îi favorizează pe ruși.
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgzOHKq4yKfTgL4gE294AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# E clar ca Trump e pro Rusia pentru ca e Krasnov ! Sper sa fie demis daca democratii preiau Congresul SUA la anul si, dupa ce va fii judecat, sa ajunga in inchisoare !
# ================================================================================
# ID: yt_Ds7YVeTvAAY_UgzQ2YwGs3RMRdrkOU94AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Parteneriat cu SUA - lol - CIUMA. Are SUA asa un renume de supermani salvatori de pe vremea lui Rambo, dar lol. Uita-ti-va si voi ce a facut SUA in Palestina, Iran, Venezuela etc. Nu va mai agatati de ei, ca poate uita si scapam si noi de napasta!
# ================================================================================
# ID: yt_39ftFtTrdnk_UgzLR3HtHMpDcGun8Jt4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# 5:00 Ualeu, am observat ca iar au scos conspiratia "Pizzagate" de la naftalina zilele astea.
# ================================================================================
# ID: yt_Ds7YVeTvAAY_UgyRhDLsmbSJ3M9_Sjh4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# A FACE ASFEL PTR Nicusor inseama sa inglobeze Romania ptr Ucraina
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgxTM3Wae3bmWoDyc3R4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Ma ia cu flori cand ma gandesc la ce se poate intampla. Ce fiinte malefice, Trump si Putin.
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgykoQwqkK9R56Y0J4R4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Tramp este un fel de Simion de la noi,,,,nu te poți baza pe el. Acest individ care face America de rușine,,,este la mina lui Putin de mult timp. Așa că acum joaca cum vrea bolșevicul criminal. Sper,,,într-o minune,totuși,,,,nu se poate că sa fie omorit un popor în fața întregii lumi,,,,
# ================================================================================
# ID: yt_wM1Y3yU_3cA_Ugzy8YyJ8WZ1Jw1PzUt4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# din moment ce nu raspunde ci bate campii, e o dovada ca ea a cerut sa fie data jos Irina
# ================================================================================
# ID: yt_pYl8Z2ypyzc_Ugw2-E3mp08uiIXyGwl4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# PS. - 1. deci PNL e cu rusii ??? ca nu se intelege nimic !! 2. ce ingerinta, concret, au facut rusii ? 3. Usr e cu francezii ? 4. dar POPORUL, POPOOORUL, CU CINE E ???
# ================================================================================
# ID: yt_pYl8Z2ypyzc_Ugw_Iv0VUN5aAIbnnol4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Domnule Isaila, felicitari pentru podcast ! Aproape toata lumea crede ca cel mai mare RAU este la momentul actual putin...dar, eu cred ca este diabolicul de trump -acest aset al rusiei a luat din primul moment al celui de-al doilea mandat, decizii prin care distruge coordonat, sistematic si cu o agresiune nemaivazuta, atat arhitectura democratica interna a SUA, institutiile de forta si de putere, cat si unitatea tuturor statelor care sprijina Ucraina. Se vede cu ochiul liber, chiar si de catre un profan ca mine....Numai ca nimeni (cu exceptia presedintelui Portugaliei) nu are curajul sa o spuna public : trump distruge actuala ordine mondiala si democratia in SUA si un lumea libera !!!
# ================================================================================
# ID: yt_pYl8Z2ypyzc_UgyrA6Fu-BqIg-qhxb94AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Mda, much ado about nothing.... spuneti ca există o legătură între persoane care fac parte din rețelele de influență ale Rusiei din România și persoane care au gravitat și gravitează în jurul lui Donald Trump. Ce aveti domne, cu spaima asta de rusi? Ca nu sunt bolsevici???
# ================================================================================
# ID: yt_vkP6FdP9iX0_UgzayNwV2DHdHENI9rR4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Gresiti, lucrez in "domeniu "aici in state, e totul propaganda americana, tehnologia militara e mult depasita de rusi si chinezi, iar unii ofiteri americani stiu asta dar nu sunt ascultati
# ================================================================================
# ID: yt_Dvw1tNAc_kU_UgxM0XGLFhTg4QAgUDB4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# eu am vazut ca ucrainienii s-au saturat de zelenski, tot sperati intr-o lovitura de stat in rusia, sau ca putin sa moara de cancer. Proteste sunt si la bucuresti impotriva regimului, pe cine intereseaza?
# ================================================================================
# ID: yt_Dvw1tNAc_kU_UgyIaBqUpnBlcSXDGRd4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Când atacă Rusia , e crimă ; când ucrainenii dirijați de CIA MI6 și Mossad comit acte de TERORISM pe teritoriul Rusiei - e OK ! 🤮🤮
# ================================================================================
# ID: yt_6hgc90sLVFw_UgwVqi8-OGqDndwTtpF4AaABAg
# Confidence: medium
# Subtype: conspiratie_suveranista
# Frumoasa poveste, domnule Baconsky. Poate ar trebui sa scrieti o carte pe modelul lui Pavel Corut din anii '90. Ca rusia are campanii de dezinformare si infiltrare in Romania nu e nici un secret. Ar fi culmea sa nu aiba cat timp Romania e tinta ideala: o tara saraca, corupta pana in maduva, putreda pe pe toate nivelurile, organizata pe caste ca in Evul Mediu. Dar cand declari senin ca rusia sustine aur (si clonele pot, sosoaca si care draqu mai sunt) ar trebui sa aduci si dovezi. Rusii n-au votat la alegeri, au votat cetateni romani si pana nu poti dovedi ca aia au fost platiti/santajati sa voteze aur sau alti tampiti sunt doar speculatii si vorbe goale. Ca tie nu-ti convine ce declara/face
# ================================================================================
# ID: yt_rG4DGen0GFw_UgxeEquDYCi4RDA2gmJ4AaABAg
# Confidence: medium
# Subtype: conspiratie_suveranista
# Listele cu persoanele care trebuiau eliminate în urma puciului programat, este reală sau este vrăjeală?
# ================================================================================
# ID: yt_1E2cXajO16k_Ugz8juwHHIYA4Jx8zwB4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Poate se străduiesc sa păstreze credință. De unde știi cata presiune este pusa peste biserica?! Uiți ca preoți și biserici în ucrain raketilor lui zele au fost bătuți, hăituiți, jefuite bisericile !!??!! Sau ai ca sarcina sa defaimezi...
# ================================================================================
# ID: yt_Mb5kDLXEKjk_UgyAgudNyzFgE5aQYgt4AaABAg
# Confidence: medium
# Subtype: conspiratie_difuza
# Super, numai ca genul ala de cunostinte nu ajuta la nimic. I-ai umplut elevului capul cu nimicuri. Informatia aia nu-l ajuta sa castige o paine, cu exceptia cazului in care devine profesor de istorie, si paseaza aceasta informatie inutila mai departe, si altor oameni, care nu au ce sa faca cu ea. Dati istoriei mult prea multa importanta, uitand ca e scrisa de castigatori, si ca intodeauna au existat interese de a denatura ceea ce s-a intamplat defapt, si care erau circumstantele.
# ================================================================================
# ID: yt_6hgc90sLVFw_Ugzw4PlIjKmVEAI97qt4AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Ce bine spunea Rudyard Kipling, ... parintele lui Mowgli, in urma cu 150 de ani "Ce ciudat si nesinceri sunt rusii astia; cand le vorbesti de Europa, ei spun ca-s asiatici dar daca le vorbesti de Asia, sustin c-ar fi ... europeni " !Asta-i ... politichia de margaritar a unui popor (nu cei multi ci, porcinele care l-au condus de secole) care ar putea produce, prin munca, bineinteles Solovei-talharule, hrana pentru tot globul in schimb, condusi de alogeni nebuni (lennin, stalin, ras-putin) produc arme, sfintite de olita de noapte din cap, precum si moarte si teroare !!!
# ================================================================================
# ID: yt_6hgc90sLVFw_UgztLUaCcmZxqny9uk94AaABAg
# Confidence: medium
# Subtype: anti_externalism_geopolitic
# Tatal , bunicii lui Baconski nu aveau fire care duceau spre Moscova....?

# %%
# elimin textele slabe și păstrez 50

REMOVE_IDS = [
    "yt_Dvw1tNAc_kU_Ugz1fzTLbi2j",
    "d5g_Wd4AaABAg",
    "yt_Dvw1tNAc_kU_UgyScTaX1LHtgukWxj54AaABAg",
    "yt_2bepCPLd2Mc_UgwrLJPCqbSMVVyiDd14AaABAg",
    "yt_Vekhmz5OPCc_Ugx0J_3TKqmVExXnmWJ4AaABAg",
    "yt_irvDTasA4Ac_UgzetskcgV0wq8PzP8l4AaABAg",
    "yt_etdRvQYxw",
    "o_UgyWeUnoCw6l0zwbw3V4AaABAg",
    "yt_HVX355umuMI_Ugz9Fx7UY1MVGkemZc14AaABAg",
    "yt_kkGOmjFf8mw_UgwgQ8WV3wVt6L_IKNF4AaABAg",
    "yt_6_Hc2S02Duw_UgwRkTZLRtfW1ljXoWl4AaABAg",
]

clean_df = (
    my_df[~my_df["id"].isin(REMOVE_IDS)]
    .head(50)
    .copy()
)

clean_df["agent"] = MY_AGENT
clean_df["slug"] = meta["slug"]
clean_df["personality"] = meta["personality"]
clean_df["speaks"] = meta["speaks"]
clean_df["definition"] = meta["definition"]

print("Texte finale:", len(clean_df))
clean_df[["id", "agent", "text"]].head()
# Out:
# Texte finale: 50
#                                               id            agent  \
# 15396  yt_joXkZDqGZQU_UgzFU0NMeTYppU_dHpd4AaABAg  Conspiraționist
# 3141   yt_X3bwh1-9nUU_Ugzkb5UdoDsVooo_b2V4AaABAg  Conspiraționist
# 11547  yt_M37Lar0c11g_UgxQUM1Vz9INIGxd0TJ4AaABAg  Conspiraționist
# 7925   yt_UDPyC0EuCLg_UgzPDvYXrj0qis3daY94AaABAg  Conspiraționist
# 15455  yt_6_Hc2S02Duw_UgzsSu-FvWam0WTNErd4AaABAg  Conspiraționist
#
#                                                     text
# 15396  Dar de românii din Ucraina care și-au pierdut ...
# 3141   Ținând cont de microfoane, unde sunt microfoan...
# 11547  Aveti incredere in cine.a juns sa fie in CSAT ...
# 7925   "Pe gratis" .. sau nu. La simulare copiii mei ...
# 15455  De ce l-or chinui pe asta nu pot sa inteleg, a...

# %% [markdown]
# ### Descrierea agentului tău
# Înainte să exporți bula curată, descrie în 5–7 rânduri ce fel de voce discursivă are agentul ales.
# Nu descrie o persoană reală. Descrie un tip de discurs observat în corpus.
# Răspunde la aceste întrebări:
# - Cum vede acest agent instituțiile, politica sau actorii publici?
# - Ce ton folosește cel mai des?
# - Ce tip de argumente sau acuzații apar frecvent?
# - Ce îl diferențiază de celelalte bule?
# - Ce ar trebui să păstreze un viitor agent AI ca să sune coerent cu această bulă?

# %% [markdown]
# descriere:
#
# -Agentul conspiraționist crede că toate instituțiile, actorii publici și politica în general ascund ceva mai mare la mijloc și că nimic din ce se spune la televizor/radio nu este adevărat de fapt.
#
# -Cel mai des agentul folosește un ton agresiv-acuzator.
#
# -Argumentele implică cel mai des actori politici care sunt proiectați drept oponenți/rivali.
#
# -Agentul conspiraționist este cel mai haotic și nu acceptă niciodată varianta documentată real.
#
# -Agentul ar trebui să păstreze tonul agresiv și să aducă în discuție alți indivizi/entități față de cei discutați.

# %%
# export bula curată pentru etapa următoare

OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

out_path = OUT_DIR / f"{meta['slug']}.jsonl"

clean_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

print("Salvat:", out_path)
# Out:
# Salvat: data\bubbles\conspirationist.jsonl

# %% [markdown]
# Am curățat bula discursivă „Conspiraționist”.
#
# Textele selectate au fost irelevante, prea scurte sau ambigue pentru a putea fi folosite.
#
# Tonul folosit este în general agresiv-acuzator față de toți actorii implicați.
#
# Corpusul final reprezintă bine vocea agentului deoarece păstrează perspectiva conspiraționistă.
#
# Un viitor agent AI construit pe această bulă ar trebui să păstreze tonul agresiv, argumentativ și orientarea spre ”adevărul ascuns”.
